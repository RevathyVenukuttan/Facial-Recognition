# %%
from matplotlib import pyplot as plt
from matplotlib.image import imread
import numpy as np
import os

# %%
dataset_path = 'D:/Academia/Sem2/Advance Stats/yalefaces/yalefaces/Train/'
dataset_dir  = os.listdir(dataset_path)

width  = 160
height = 233

# %%
folder = os.fsencode(dataset_path)

filenames = []

for file in os.listdir(folder):
    filename = os.fsdecode(file)
    if filename.endswith( ('.jpg') ): # whatever file types you're using...
        filenames.append(filename)

filenames.sort()
len(filenames)
# Out:
# 133

# %%
train_image_names = ['subject01.wink-0.jpg',
 'subject01.wink-1.jpg',
 'subject01.wink-2.jpg',
 'subject01.wink-3.jpg',
 'subject01.wink-5.jpg',
 'subject01.wink-6.jpg',
 'subject01.wink-7.jpg',
 'subject01.wink-8.jpg',
 'subject01.wink-9.jpg',
 'subject02.wink-0.jpg',
 'subject02.wink-1.jpg',
 'subject02.wink-2.jpg',
 'subject02.wink-3.jpg',
 'subject02.wink-4.jpg',
 'subject02.wink-5.jpg',
 'subject02.wink-6.jpg',
 'subject02.wink-7.jpg',
 'subject02.wink-8.jpg',
 'subject02.wink-9.jpg',
 'subject03.wink-0.jpg',
 'subject03.wink-1.jpg',
 'subject03.wink-2.jpg',
 'subject03.wink-3.jpg',
 'subject03.wink-4.jpg',
 'subject03.wink-5.jpg',
 'subject03.wink-6.jpg',
 'subject03.wink-7.jpg',
 'subject03.wink-8.jpg',
 'subject03.wink-9.jpg',
 'subject04.wink-0.jpg',
 'subject04.wink-1.jpg',
 'subject04.wink-2.jpg',
 'subject04.wink-3.jpg',
 'subject04.wink-4.jpg',
 'subject04.wink-5.jpg',
 'subject04.wink-6.jpg',
 'subject04.wink-7.jpg',
 'subject04.wink-8.jpg',
 'subject04.wink-9.jpg',
 'subject05.wink-0.jpg',
 'subject05.wink-1.jpg',
 'subject05.wink-2.jpg',
 'subject05.wink-3.jpg',
 'subject05.wink-4.jpg',
 'subject05.wink-5.jpg',
 'subject05.wink-6.jpg',
 'subject05.wink-7.jpg',
 'subject05.wink-8.jpg',
 'subject05.wink-9.jpg',
 'subject07.wink-0.jpg',
 'subject07.wink-1.jpg',
 'subject07.wink-2.jpg',
 'subject07.wink-3.jpg',
 'subject07.wink-4.jpg',
 'subject07.wink-5.jpg',
 'subject07.wink-6.jpg',
 'subject07.wink-7.jpg',
 'subject07.wink-8.jpg',
 'subject07.wink-9.jpg',
 'subject08.wink-0.jpg',
 'subject08.wink-1.jpg',
 'subject08.wink-2.jpg',
 'subject08.wink-3.jpg',
 'subject08.wink-4.jpg',
 'subject08.wink-5.jpg',
 'subject08.wink-6.jpg',
 'subject08.wink-7.jpg',
 'subject08.wink-8.jpg',
 'subject09.wink-0.jpg',
 'subject09.wink-1.jpg',
 'subject09.wink-2.jpg',
 'subject09.wink-3.jpg',
 'subject09.wink-4.jpg',
 'subject09.wink-5.jpg',
 'subject09.wink-6.jpg',
 'subject09.wink-7.jpg',
 'subject09.wink-8.jpg',
 'subject09.wink-9.jpg',
 'subject10.wink-0.jpg',
 'subject10.wink-1.jpg',
 'subject10.wink-2.jpg',
 'subject10.wink-4.jpg',
 'subject10.wink-5.jpg',
 'subject10.wink-6.jpg',
 'subject10.wink-7.jpg',
 'subject10.wink-8.jpg',
 'subject10.wink-9.jpg',
 'subject11.wink-0.jpg',
 'subject11.wink-1.jpg',
 'subject11.wink-2.jpg',
 'subject11.wink-3.jpg',
 'subject11.wink-4.jpg',
 'subject11.wink-5.jpg',
 'subject11.wink-6.jpg',
 'subject11.wink-7.jpg',
 'subject11.wink-8.jpg',
 'subject11.wink-9.jpg',
 'subject12.wink-0.jpg',
 'subject12.wink-1.jpg',
 'subject12.wink-3.jpg',
 'subject12.wink-4.jpg',
 'subject12.wink-5.jpg',
 'subject12.wink-6.jpg',
 'subject12.wink-9.jpg',
 'subject13.wink-0.jpg',
 'subject13.wink-1.jpg',
 'subject13.wink-2.jpg',
 'subject13.wink-3.jpg',
 'subject13.wink-4.jpg',
 'subject13.wink-5.jpg',
 'subject13.wink-6.jpg',
 'subject13.wink-7.jpg',
 'subject13.wink-8.jpg',
 'subject13.wink-9.jpg',
 'subject14.wink-0.jpg',
 'subject14.wink-1.jpg',
 'subject14.wink-2.jpg',
 'subject14.wink-3.jpg',
 'subject14.wink-4.jpg',
 'subject14.wink-5.jpg',
 'subject14.wink-6.jpg',
 'subject14.wink-8.jpg',
 'subject14.wink-9.jpg',
 'subject15.wink-0.jpg',
 'subject15.wink-1.jpg',
 'subject15.wink-2.jpg',
 'subject15.wink-3.jpg',
 'subject15.wink-4.jpg',
 'subject15.wink-5.jpg',
 'subject15.wink-6.jpg',
 'subject15.wink-7.jpg',
 'subject15.wink-8.jpg',
 'subject15.wink-9.jpg']

# %%
#Train
#print('Train Images:')

training_tensor   = np.ndarray(shape=(len(train_image_names), height*width), dtype=np.float64)

for i in range(len(train_image_names)):
    img = plt.imread(dataset_path + train_image_names[i])
    training_tensor[i,:] = np.array(img, dtype='float64').flatten()
    plt.subplot(14,10,1+i)
    plt.imshow(img, cmap='gray')
    plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
test_path = 'D:/Academia/Sem2/Advance Stats/yalefaces/yalefaces/Test/'
test_dir  = os.listdir(test_path)

# %%
folder = os.fsencode(test_path)
test = []
for file in os.listdir(folder):
    filename = os.fsdecode(file)
    if filename.endswith( ('.jpg') ): 
        test.append(filename)
test.sort()
len(test)
# Out:
# 28

# %%
#print('Test Images:')
test_image_names = ['apple.jpg',
 'subject01.wink-7.jpg',
 'subject01.wink-8.jpg',
 'subject02.wink-7.jpg',
 'subject02.wink-8.jpg',
 'subject03.wink-7.jpg',
 'subject03.wink-8.jpg',
 'subject04.wink-7.jpg',
 'subject04.wink-8.jpg',
 'subject05.wink-7.jpg',
 'subject05.wink-8.jpg',
 'subject06.wink-2.jpg',
 'subject06.wink-4.jpg',
 'subject07.wink-8.jpg',
 'subject08.wink-7.jpg',
 'subject08.wink-8.jpg',
 'subject09.wink-7.jpg',
 'subject09.wink-8.jpg',
 'subject10.wink-7.jpg',
 'subject10.wink-8.jpg',
 'subject11.wink-7.jpg',
 'subject11.wink-8.jpg',
 'subject13.wink-7.jpg',
 'subject13.wink-8.jpg',
 'subject14.wink-7.jpg',
 'subject14.wink-8.jpg',
 'subject15.wink-7.jpg',
 'subject15.wink-8.jpg']

# %%
testing_tensor   = np.ndarray(shape=(len(test_image_names), height*width), dtype=np.float64)

for i in range(len(test_image_names)):
    img = imread(test_path + test_image_names[i])
    testing_tensor[i,:] = np.array(img, dtype='float64').flatten()
    plt.subplot(2,14,1+i)
    #plt.title(test_image_names[i].split('.')[0][-2:]+test_image_names[i].split('.')[1])
    plt.imshow(img, cmap='gray')
    plt.subplots_adjust(right=1.2, top=1.2)
    plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
#Mean faces 
mean_face = np.zeros((1,height*width))

for i in training_tensor:
    mean_face = np.add(mean_face,i)

mean_face = np.divide(mean_face,float(len(train_image_names))).flatten()

plt.imshow(mean_face.reshape(height, width), cmap='gray')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
#normalized faces
normalised_training_tensor = np.ndarray(shape=(len(train_image_names), height*width))

#subtract mean
for i in range(len(train_image_names)):
    normalised_training_tensor[i] = np.subtract(training_tensor[i],mean_face)

# %%
#display normalized faces
#for i in range(len(train_image_names)):
img = normalised_training_tensor[60].reshape(height,width)
    #plt.subplot(2,4,1+i)
plt.imshow(img, cmap='gray')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
#covariance matrix
cov_matrix = np.cov(normalised_training_tensor)
cov_matrix = np.divide(cov_matrix,8.0)
print('Covariance matrix of X: \n%s' %cov_matrix)
# Out:
# Covariance matrix of X:
# [[291.51908751 245.88331297 116.08921236 ... -66.46537081 142.54589933
#   122.56184377]
#  [245.88331297 325.73418899 125.25442712 ... -89.53196061 161.51711217
#   155.84872787]
#  [116.08921236 125.25442712 359.39503763 ...  15.10389791  65.23367425
#    53.15531612]
#  ...
#  [-66.46537081 -89.53196061  15.10389791 ... 384.35158375 -48.15778313
#   -56.78008708]
#  [142.54589933 161.51711217  65.23367425 ... -48.15778313 782.32817181
#   679.44479599]
#  [122.56184377 155.84872787  53.15531612 ... -56.78008708 679.44479599
#   729.48694227]]

# %%
eigenvalues, eigenvectors, = np.linalg.eig(cov_matrix)
print('Eigenvectors of Cov(X): \n%s' %eigenvectors)
print('\nEigenvalues of Cov(X): \n%s' %eigenvalues)
# Out:
# Eigenvectors of Cov(X):
# [[-0.00930381+0.j -0.08863892+0.j -0.01806753+0.j ... -0.00377727+0.j
#   -0.0049865 +0.j -0.00490613+0.j]
#  [-0.00159283+0.j -0.09650801+0.j -0.01947482+0.j ... -0.00377727+0.j
#   -0.0049865 +0.j -0.00490613+0.j]
#  [-0.07728957+0.j -0.0644788 +0.j -0.07473053+0.j ... -0.00377727+0.j
#   -0.0049865 +0.j -0.00490613+0.j]
#  ...
#  [-0.02999835+0.j  0.03007279+0.j  0.06085446+0.j ... -0.00377727+0.j
#   -0.0049865 +0.j -0.00490613+0.j]
#  [ 0.04843733+0.j -0.20683335+0.j  0.09280092+0.j ... -0.00377727+0.j
#   -0.0049865 +0.j -0.00490613+0.j]
#  [ 0.04033251+0.j -0.20105813+0.j  0.09292572+0.j ... -0.00377727+0.j
#   -0.0049865 +0.j -0.00490613+0.j]]
#
# Eigenvalues of Cov(X):
# [ 1.06905135e+04+0.00000000e+00j  8.50332220e+03+0.00000000e+00j
#   5.87486832e+03+0.00000000e+00j  4.80741171e+03+0.00000000e+00j
#   3.45369970e+03+0.00000000e+00j  2.52069694e+03+0.00000000e+00j
#   2.25509790e+03+0.00000000e+00j  1.77172057e+03+0.00000000e+00j
# ...

# %%
eig_pairs = [(eigenvalues[index], eigenvectors[:,index]) for index in range(len(eigenvalues))]

# Sort the eigen pairs in descending order:
eig_pairs.sort(reverse=True)
eigvalues_sort  = [eig_pairs[index][0] for index in range(len(eigenvalues))]
eigvectors_sort = [eig_pairs[index][1] for index in range(len(eigenvalues))]

# %%
var_comp_sum = np.cumsum(eigvalues_sort)/sum(eigvalues_sort)

# Show cumulative proportion of varaince with respect to components
print("Cumulative proportion of variance explained vector: \n%s" %var_comp_sum)

# x-axis for number of principal components kept
num_comp = range(1,len(eigvalues_sort)+1)
plt.title('Cum. Prop. Variance Explain and Components Kept')
plt.xlabel('Principal Components')
plt.ylabel('Proportion of Variance Explained')

plt.scatter(num_comp, var_comp_sum)
plt.show()
# Out:
# Cumulative proportion of variance explained vector:
# [0.17380709+0.00000000e+00j 0.31205468+0.00000000e+00j
#  0.40756869+0.00000000e+00j 0.48572792+0.00000000e+00j
#  0.5418784 +0.00000000e+00j 0.58286006+0.00000000e+00j
#  0.6195236 +0.00000000e+00j 0.64832835+0.00000000e+00j
#  0.67531133+0.00000000e+00j 0.6985966 +0.00000000e+00j
#  0.71884976+0.00000000e+00j 0.73588937+0.00000000e+00j
#  0.75105768+0.00000000e+00j 0.76429761+0.00000000e+00j
#  0.77517724+0.00000000e+00j 0.78590756+0.00000000e+00j
#  0.79603489+0.00000000e+00j 0.80498303+0.00000000e+00j
#  0.81306954+0.00000000e+00j 0.82083868+0.00000000e+00j
#  0.82850958+0.00000000e+00j 0.83566703+0.00000000e+00j
#  0.84190753+0.00000000e+00j 0.8477554 +0.00000000e+00j
#  0.8532445 +0.00000000e+00j 0.85843971+0.00000000e+00j
#  0.86335181+0.00000000e+00j 0.86813934+0.00000000e+00j
#  0.87266797+0.00000000e+00j 0.87709279+0.00000000e+00j
#  0.88131622+0.00000000e+00j 0.88536987+0.00000000e+00j
# ...

# %%
reduced_data = np.array(eigvectors_sort[:20], dtype = 'float64').transpose()
reduced_data
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   """Entry point for launching an IPython kernel.
# array([[-0.00930381, -0.08863892, -0.01806753, ...,  0.0969333 ,
#         -0.05757802,  0.04527489],
#        [-0.00159283, -0.09650801, -0.01947482, ...,  0.12193144,
#         -0.04081766,  0.02120482],
#        [-0.07728957, -0.0644788 , -0.07473053, ..., -0.0300232 ,
#          0.07026712, -0.00934964],
#        ...,
#        [-0.02999835,  0.03007279,  0.06085446, ..., -0.20121054,
#         -0.05600878, -0.02686675],
#        [ 0.04843733, -0.20683335,  0.09280092, ...,  0.12208362,
#          0.11133699,  0.03906397],
#        [ 0.04033251, -0.20105813,  0.09292572, ...,  0.03130291,
#          0.09406668,  0.04903194]])

# %%
proj_data = np.dot(training_tensor.transpose(),reduced_data)
proj_data = proj_data.transpose()
proj_data
# Out:
# array([[-1.55946081e+01, -1.33273020e+01, -1.54043450e+01, ...,
#          9.59232693e-14,  9.59232693e-14,  9.59232693e-14],
#        [ 1.45798737e+01,  1.28412806e+01,  1.21447669e+01, ...,
#         -3.87467836e-14, -3.87467836e-14, -3.87467836e-14],
#        [ 5.68480181e+00,  6.35519602e+00,  9.21041581e+00, ...,
#         -7.69939668e-14, -7.69939668e-14, -7.69939668e-14],
#        ...,
#        [-6.14980288e+00, -4.98278122e+00, -4.21863673e+00, ...,
#          1.79800619e-13,  1.79800619e-13,  1.79800619e-13],
#        [-4.45259430e+00, -9.42372053e+00, -1.10917085e+01, ...,
#         -5.06761300e-13, -5.06761300e-13, -5.06761300e-13],
#        [-1.18041373e+00,  2.22223311e+00,  5.45868831e+00, ...,
#          1.94566585e-13,  1.94566585e-13,  1.94566585e-13]])

# %%
#for i in range(proj_data.shape[0]):
img = proj_data[0].reshape(height,width)
    #plt.subplot(2,4,1+i)
plt.imshow(img, cmap='gray')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
#2nd eigen vector
img = proj_data[1].reshape(height,width)
    #plt.subplot(2,4,1+i)
plt.imshow(img, cmap='gray')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
#3rd eigen vector
img = proj_data[2].reshape(height,width)
    #plt.subplot(2,4,1+i)
plt.imshow(img, cmap='gray')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
#4th eigen vector
img = proj_data[3].reshape(height,width)
    #plt.subplot(2,4,1+i)
plt.imshow(img, cmap='gray')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
#20th eigen vector
img = proj_data[19].reshape(height,width)
    #plt.subplot(2,4,1+i)
plt.imshow(img, cmap='gray')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
w = np.array([np.dot(proj_data,i) for i in normalised_training_tensor])
w
# Out:
# array([[ 4.71141319e+06, -1.81028973e+08,  5.28621568e+07, ...,
#          1.00832190e+07, -4.20724782e+07,  8.40395892e+06],
#        [ 2.46168797e+07, -2.06940845e+08,  3.88917693e+07, ...,
#          1.49797053e+07, -3.50219369e+07,  4.70796695e+06],
#        [-2.41847129e+08, -1.57696540e+08, -1.19693020e+08, ...,
#         -5.70307914e+06,  5.96362070e+06, -1.07290286e+06],
#        ...,
#        [-8.31000302e+07,  9.22289413e+07,  1.37459879e+08, ...,
#         -3.51533011e+07, -2.05429246e+07, -3.11679746e+06],
#        [ 1.52934960e+08, -5.26425359e+08,  1.58916944e+08, ...,
#          2.02925140e+07,  1.79741182e+07,  5.48226833e+06],
#        [ 1.18738147e+08, -5.22416945e+08,  1.38588875e+08, ...,
#          6.80835015e+06,  2.35640231e+07,  6.42839416e+06]])

# %%
#unknown faces
from skimage import io
unknown_face        = plt.imread('D:/Academia/Sem2/Advance Stats/yalefaces/yalefaces/sub6/subject06.wink-5.jpg')
unknown_face_vector = np.array(unknown_face, dtype='float64').flatten()

plt.imshow(unknown_face, cmap='gray')
plt.title('Unknown face')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
normalised_uface_vector = np.subtract(unknown_face_vector,mean_face)

plt.imshow(normalised_uface_vector.reshape(height, width), cmap='gray')
plt.title('Normalised unknown face')
plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
plt.show()

# %%
w_unknown = np.dot(proj_data, unknown_face_vector)
w_unknown

diff  = w - w_unknown
norms = np.linalg.norm(diff, axis=1)
print(norms)
min(norms)
# Out:
# [6.00148092e+08 6.17695010e+08 9.12670383e+08 1.10448443e+09
#  6.31882212e+08 1.13158081e+09 6.14622846e+08 6.38466453e+08
#  6.85253906e+08 8.31832401e+08 6.98755838e+08 9.03486902e+08
#  1.04310507e+09 8.54932073e+08 8.54932073e+08 8.42651651e+08
#  8.29069713e+08 8.48225826e+08 8.79570104e+08 9.25236537e+08
#  7.37561180e+08 6.68579115e+08 1.16702848e+09 6.14990592e+08
#  6.14990592e+08 1.12038393e+09 6.13842885e+08 6.50869277e+08
#  6.64357498e+08 8.63284353e+08 1.02500925e+09 9.82084502e+08
#  1.11268615e+09 8.89748550e+08 1.03989942e+09 1.14876926e+09
#  1.03989942e+09 9.86753289e+08 9.57350545e+08 6.80396908e+08
#  6.08314310e+08 5.92158022e+08 9.19274571e+08 6.37487978e+08
#  5.97468470e+08 9.80950811e+08 5.77752809e+08 5.81958710e+08
#  6.44996625e+08 1.03019202e+09 6.31262376e+08 8.60420866e+08
#  1.20690908e+09 8.16738800e+08 8.16738800e+08 1.03953876e+09
#  8.42887816e+08 8.08216263e+08 7.70818313e+08 7.10001650e+08
# ...

# %%
count        = 0
num_images   = 0
correct_pred = 0
def recogniser(img, train_image_names,proj_data,w):
    global count,highest_min,num_images,correct_pred
    unknown_face        = plt.imread('D:/Academia/Sem2/Advance Stats/yalefaces/yalefaces/Test/'+img)
    num_images          += 1
    unknown_face_vector = np.array(unknown_face, dtype='float64').flatten()
    normalised_uface_vector = np.subtract(unknown_face_vector,mean_face)
    
    plt.subplot(15,6,1+count)
    plt.imshow(unknown_face, cmap='gray')
    plt.title('Input:'+'.'.join(img.split('.')[:2]))
    plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
    count+=1
    
    w_unknown = np.dot(proj_data, normalised_uface_vector)
    diff  = w - w_unknown
    norms = np.linalg.norm(diff, axis=1)
    index = np.argmin(norms)
    
    t1 = 510200084
    
    t0 = 480000022
    
    
    if norms[index] < t1:
        plt.subplot(15,6,1+count)
        if norms[index] < t0: # It's a face
            if img.split('.')[0] == train_image_names[index].split('.')[0]:
                plt.title('Matched:'+'.'.join(train_image_names[index].split('.')[:2]), color='g')
                plt.imshow(imread('D:/Academia/Sem2/Advance Stats/yalefaces/yalefaces/Train/'+train_image_names[index]), cmap='gray')
                
                correct_pred += 1
            else:
                plt.title('Matched:'+'.'.join(train_image_names[index].split('.')[:2]), color='r')
                plt.imshow(imread('D:/Academia/Sem2/Advance Stats/yalefaces/yalefaces/Train/'+train_image_names[index]), cmap='gray')
        else:
            if img.split('.')[0] not in [i.split('.')[0] for i in train_image_names] and img.split('.')[0] != 'apple':
                plt.title('Unknown face!', color='g')
                correct_pred += 1
            else:
                plt.title('Unknown face!', color='r')
        plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
        plt.subplots_adjust(right=1.2, top=2.5)
    else:     
        plt.subplot(15,6,1+count)
        if len(img.split('.')) == 3:
            plt.title('Not a face!', color='r')
        else:
            plt.title('Not a face!', color='g')
            correct_pred += 1
        plt.tick_params(labelleft='off', labelbottom='off', bottom='off',top='off',right='off',left='off', which='both')
    count+=1

fig = plt.figure(figsize=(15, 15))
for i in range(len(test_image_names)):
    recogniser(test_image_names[i], train_image_names,proj_data,w)

#plt.show()

#print('Correct predictions: {}/{} = {}%'.format(correct_pred, num_images, correct_pred/num_images*100.00))

# %%
    w_unknown = np.dot(proj_data, normalised_uface_vector)
    diff  = w - w_unknown
    norms = np.linalg.norm(diff, axis=1)
    index = np.argmin(norms)
    norms[index]
# Out:
# 232928739.33477008
